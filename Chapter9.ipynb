# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time

# %%
def PAbsorb(p0,nmax,p,r):
  q = 1-p-r
  pA = np.zeros((43,nmax))
  flux = np.zeros((1,nmax))
  pA[:,0] = p0
